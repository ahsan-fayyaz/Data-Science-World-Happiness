# %% [markdown]
# # Import all necessary modules

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.image as mpimg
import scipy.stats as stats

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Full Dataset

# %%
full_df = pd.read_csv("./Datasets/Cleaned_Datasets/full_dataset.csv", header=0)
full_df.head(15)
# Out:
#         country  happiness_score  gdp_per_capita  social_support  \
# 0   Afghanistan         3.594628        7.650843        0.508245
# 1       Albania         5.019427        9.384397        0.716316
# 2       Algeria         5.389717        9.328897        0.803582
# 3        Angola         4.420299        8.989725        0.737973
# 4     Argentina         6.310166       10.033868        0.904423
# 5       Armenia         4.513624        9.270409        0.718620
# 6     Australia         7.282024       10.755507        0.947253
# 7       Austria         7.242227       10.886958        0.929600
# 8    Azerbaijan         4.940989        9.519592        0.770649
# 9       Bahrain         6.001723       10.730848        0.880093
# 10   Bangladesh         4.754565        8.128453        0.607105
# 11      Belarus         5.571155        9.760055        0.906551
# 12      Belgium         6.981520       10.798704        0.920018
# ...

# %% [markdown]
# # Data Correlation Visualizations

# %% [markdown]
# Our dependent variable that we want to predict is `happiness_score`
# Taking a look at how different features correlate with it will help get a solid understanding of our data

# %%
full_df.corr(method="pearson")["happiness_score"].sort_values(ascending=False)
# Out:
# happiness_score                   1.000000
# gdp_per_capita                    0.846887
# life_expectancy                   0.820468
# social_support                    0.781526
# clean_water_per_100_people        0.731042
# doctors_per_10000_people          0.673451
# freedom                           0.632455
# suicide_rate_per_100000_people    0.236863
# corruption                       -0.487522
# Name: happiness_score, dtype: float64

# %% [markdown]
# ####  Observation: world happiness has a
# * strong positive correlation with `gdp_per_capita`
# * strong positive correlation with `life_expectancy`
# * strong positive correlation with `social_support`
# * strong positive correlation with `clean_water_per_100_people`
# * somewhat strong correlation with `freedom`
# * no correlation with `suicide_rate_per_100000_people`
# * inversely correlated with `corruption`

# %% [markdown]
# ### Heat Map (Correlation factor between each column)

# %%
data_Corr = full_df.corr(method = "pearson")
plt.figure(figsize = (10,10))
sb.heatmap(data_Corr, annot = True)

# %% [markdown]
# ### Summary

# %%
full_df.describe()
# Out:
#        happiness_score  gdp_per_capita  social_support  life_expectancy  \
# count       140.000000      140.000000      140.000000       140.000000
# mean          5.424848        9.301535        0.805777        62.805440
# std           1.103782        1.212501        0.118027         7.636191
# min           3.514954        6.722510        0.402559        43.356001
# 25%           4.465380        8.297707        0.745606        56.967857
# 50%           5.309331        9.396615        0.826084        65.065667
# 75%           6.263767       10.289785        0.902506        67.945536
# max           7.680305       11.607032        0.977578        75.358461
#
#           freedom  corruption  clean_water_per_100_people  \
# count  140.000000  140.000000                  140.000000
# mean     0.741846    0.733355                   77.711177
# std      0.125386    0.183885                   23.426713
# min      0.451014    0.097752                   21.435000
# ...

# %% [markdown]
# ### Top Ten Most Happiest Country

# %%
full_df.sort_values(by = "happiness_score", ascending = False). head(10)
# Out:
#          country  happiness_score  gdp_per_capita  social_support  \
# 33       Denmark         7.680305       10.879287        0.957209
# 41       Finland         7.597216       10.749943        0.948971
# 121  Switzerland         7.548228       11.095401        0.943610
# 96        Norway         7.512566       11.039174        0.950364
# 91   Netherlands         7.466292       10.886792        0.933519
# 55       Iceland         7.446581       10.860745        0.977578
# 24        Canada         7.376319       10.748257        0.935470
# 120       Sweden         7.369527       10.819609        0.927842
# 92   New Zealand         7.310304       10.583125        0.952875
# 6      Australia         7.282024       10.755507        0.947253
#
#      life_expectancy   freedom  corruption  clean_water_per_100_people  \
# 33         71.169333  0.945131    0.200404                  100.000000
# 41         71.180000  0.939703    0.248932                  100.000000
# ...

# %% [markdown]
# ### Top Ten least happiest country

# %%
full_df.sort_values(by = "happiness_score", ascending = True). head(10)
# Out:
#                       country  happiness_score  gdp_per_capita  \
# 25   Central African Republic         3.514954        6.960998
# 21                    Burundi         3.548124        6.722510
# 126                      Togo         3.555060        7.239263
# 0                 Afghanistan         3.594628        7.650843
# 106                    Rwanda         3.654473        7.451130
# 124                  Tanzania         3.697284        7.700381
# 139                  Zimbabwe         3.882689        7.850429
# 137                     Yemen         3.912124        8.102699
# 29                    Comoros         3.943963        7.991248
# 52                      Haiti         3.954194        7.446694
#
#      social_support  life_expectancy   freedom  corruption  \
# 25         0.402559        43.356001  0.680430    0.842129
# 21         0.417652        50.916000  0.451014    0.732270
# 126        0.456104        52.837778  0.623363    0.803149
# ...

# %%
sb.displot(full_df['happiness_score'], kind="kde")

# %% [markdown]
# ***

# %% [markdown]
# ### Helper Functions

# %%
# This function will help to evaluate linear relationship for two variables

def evaluate_linear_relationship(a, b):
    slope = np.cov(a, b, bias=True)[0][1] / np.var(a)
    intercept = np.mean(b) - (slope * np.mean(a))
    predictions = (slope * a) + intercept
    residuals = b - predictions
    return slope, intercept, predictions, residuals

# This function will help evaluate the intervals when we reach Confidence Intervals and Predication Intervals part
def get_intervals(a, b, residuals):
    t = stats.t(df=len(a) - 2).ppf(0.975)
    s_err = np.sum(np.power(residuals, 2))
    confidence_interval = t * np.sqrt((s_err/(len(a) - 2))*(1/len(a) + (np.power((a - a.mean()), 2)/((np.sum(np.power(a,2))) - len(full_df)*(np.power(a.mean(),2))))))
    prediction_interval = t * (np.std(residuals))
    return abs(confidence_interval), prediction_interval

# %% [markdown]
# ***

# %% [markdown]
# ### 1. `happiness_score` vs `gdp_per_capita`

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(full_df["gdp_per_capita"], full_df['happiness_score'])

# %%
print("Slope is ", slope)
print("Interscept is", intercept)
# Out:
# Slope is  0.7709509994660471
# Interscept is -1.7461801855523147

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["gdp_per_capita"],full_df['happiness_score'])
sorted_order = np.argsort(full_df["gdp_per_capita"])
plt.plot(full_df["gdp_per_capita"][sorted_order], predictions[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('GDP Per Capita')
fig.suptitle("Relationship between GDP per capita and World Happiness", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between GDP per capita and World Happiness')

# %% [markdown]
# A positive linear relationship is observed between World Happiness and GDP per capita
# The Slope tells us that for every one unit increase in GDP, there is an increase of 0.770 in the happiness score

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["gdp_per_capita"], residuals)
sorted_order = np.argsort(full_df["gdp_per_capita"])
plt.plot([full_df["gdp_per_capita"].min(), full_df["gdp_per_capita"].max()], [0,0], linestyle='dotted')
plt.xlabel('GDP Per Capita')
plt.ylabel('Happiness Score')
fig.suptitle('Relationship between GDP and World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between GDP and World Happiness')

# %% [markdown]
# #### R-squared Value

# %%
np.var(predictions) / np.var(full_df["gdp_per_capita"])
# Out:
# 0.5943654435776968

# %% [markdown]
# #### Analysis

# %% [markdown]
# There is an R-squared value of 59.4% here depicts 59.4% of the variation in the Happiness Score is accounted for by its regression on GDP per capita.

# %% [markdown]
# #### Confidence Intervals and Predication Intervals

# %%
ci, pi = get_intervals(full_df["gdp_per_capita"], full_df["happiness_score"], residuals)
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["gdp_per_capita"],full_df["happiness_score"])
sorted_order = np.argsort(full_df["gdp_per_capita"])
plt.plot(full_df["gdp_per_capita"][sorted_order], predictions[sorted_order], label='Regression Line')
plt.plot(full_df["gdp_per_capita"][sorted_order], (predictions + ci)[sorted_order], color='orange', label='Confidence Interval')
plt.plot(full_df["gdp_per_capita"][sorted_order], (predictions - ci)[sorted_order], color='orange', label='_Confidence Interval')
plt.plot(full_df["gdp_per_capita"][sorted_order], (predictions + pi)[sorted_order], color='red', label='Prediction Interval', linestyle='dotted')
plt.plot(full_df["gdp_per_capita"][sorted_order], (predictions - pi)[sorted_order], color='red', label='_Prediction Interval', linestyle='dotted')
plt.xlabel('GDP Per Capita')
plt.ylabel('Happiness Score')
plt.legend()
fig.suptitle('World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'World Happiness')

# %% [markdown]
# ### Observation:
#
# The orange lines are the 95% confidence interval of where the mean Y value for a given X value will lay, and the red lines are the 95% confidence interval of where a new Y value for a given X value could land. Most of the observed points are between the red lines - as 95% of them should be.

# %% [markdown]
# ***

# %% [markdown]
# ### 2. `happiness_score` vs `social_support`

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(full_df["social_support"], full_df['happiness_score'])

# %%
print("Slope is ", slope)
print("Interscept is", intercept)
# Out:
# Slope is  7.308801830053264
# Interscept is -0.46441933952599257

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["social_support"],full_df['happiness_score'])
sorted_order = np.argsort(full_df["social_support"])
plt.plot(full_df["social_support"][sorted_order], predictions[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('Social Support')
fig.suptitle("Relationship between Social Support and World Happiness", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Social Support and World Happiness')

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["social_support"], residuals)
sorted_order = np.argsort(full_df["social_support"])
plt.plot([full_df["social_support"].min(), full_df["social_support"].max()], [0,0], linestyle='dotted')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
fig.suptitle('Relationship between Social Support and World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Social Support and World Happiness')

# %% [markdown]
# #### R-squared Value

# %%
np.var(predictions) / np.var(full_df["social_support"])
# Out:
# 53.41858419098995

# %% [markdown]
# #### Analysis

# %% [markdown]
# There is an R-squared value of 53.42% here depicts 53.42% of the variation in the Happiness Score is accounted for by its regression on Social Support.

# %% [markdown]
# #### Confidence Intervals and Predication Intervals

# %%
ci, pi = get_intervals(full_df["social_support"], full_df["happiness_score"], residuals)
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["social_support"],full_df["happiness_score"])
sorted_order = np.argsort(full_df["social_support"])
plt.plot(full_df["social_support"][sorted_order], predictions[sorted_order], label='Regression Line')
plt.plot(full_df["social_support"][sorted_order], (predictions + ci)[sorted_order], color='orange', label='Confidence Interval')
plt.plot(full_df["social_support"][sorted_order], (predictions - ci)[sorted_order], color='orange', label='_Confidence Interval')
plt.plot(full_df["social_support"][sorted_order], (predictions + pi)[sorted_order], color='red', label='Prediction Interval', linestyle='dotted')
plt.plot(full_df["social_support"][sorted_order], (predictions - pi)[sorted_order], color='red', label='_Prediction Interval', linestyle='dotted')
plt.xlabel('Social Support')
plt.ylabel('Happiness Score')
plt.legend()
fig.suptitle('World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'World Happiness')

# %% [markdown]
# ### Observation:
#
# The orange lines are the 95% confidence interval of where the mean Y value for a given X value will lay, and the red lines are the 95% confidence interval of where a new Y value for a given X value could land. Most of the observed points are between the red lines - as 95% of them should be.

# %% [markdown]
# ***

# %% [markdown]
# ### 3. `happiness_score` vs `life_expectancy`

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(full_df["life_expectancy"], full_df['happiness_score'])

# %%
print("Slope is ", slope)
print("Interscept is", intercept)
# Out:
# Slope is  0.1185955293729344
# Interscept is -2.023596495067892

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["life_expectancy"],full_df['happiness_score'])
sorted_order = np.argsort(full_df["life_expectancy"])
plt.plot(full_df["life_expectancy"][sorted_order], predictions[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('Life Expectancy')
fig.suptitle("Relationship between Life Expectancy and Happiness Score", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Life Expectancy and Happiness Score')

# %% [markdown]
# A positive linear relationship is observed between World Happiness and Life Expectancy.
# The Slope tells us that for every one unit increase in life expectancy, there is an increase of 0.11 in the happiness score

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["life_expectancy"], residuals)
sorted_order = np.argsort(full_df["life_expectancy"])
plt.plot([full_df["life_expectancy"].min(), full_df["life_expectancy"].max()], [0,0], linestyle='dotted')
plt.xlabel('Life Expectancy')
plt.ylabel('Happiness Score')
fig.suptitle('Relationship between Life Expectancy and Happiness Score', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Life Expectancy and Happiness Score')

# %% [markdown]
# #### R-squared Value

# %%
np.var(predictions) / np.var(full_df["life_expectancy"])
# Out:
# 0.01406489958724654

# %% [markdown]
# #### Analysis

# %% [markdown]
# There is an R-squared value of 1.4% here depicts 1.4% of the variation in the Happiness Score is accounted for by its regression on Life Expectancy.

# %% [markdown]
# #### Confidence Intervals and Predication Intervals

# %%
ci, pi = get_intervals(full_df["life_expectancy"], full_df["happiness_score"], residuals)
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["life_expectancy"],full_df["happiness_score"])
sorted_order = np.argsort(full_df["life_expectancy"])
plt.plot(full_df["life_expectancy"][sorted_order], predictions[sorted_order], label='Regression Line')
plt.plot(full_df["life_expectancy"][sorted_order], (predictions + ci)[sorted_order], color='orange', label='Confidence Interval')
plt.plot(full_df["life_expectancy"][sorted_order], (predictions - ci)[sorted_order], color='orange', label='_Confidence Interval')
plt.plot(full_df["life_expectancy"][sorted_order], (predictions + pi)[sorted_order], color='red', label='Prediction Interval', linestyle='dotted')
plt.plot(full_df["life_expectancy"][sorted_order], (predictions - pi)[sorted_order], color='red', label='_Prediction Interval', linestyle='dotted')
plt.xlabel('Life Expectancy')
plt.ylabel('Happiness Score')
plt.legend()
fig.suptitle('World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'World Happiness')

# %% [markdown]
# ### Observation:
#
# The orange lines are the 95% confidence interval of where the mean Y value for a given X value will lay, and the red lines are the 95% confidence interval of where a new Y value for a given X value could land. Most of the observed points are between the red lines - as 95% of them should be.

# %% [markdown]
# ***

# %% [markdown]
# ### 4. `happiness_score` vs `clean_water_per_100_people`

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(full_df["clean_water_per_100_people"], full_df['happiness_score'])

# %%
print("Slope is ", slope)
print("Interscept is", intercept)
# Out:
# Slope is  0.03444403937985279
# Interscept is 2.748161050023536

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["clean_water_per_100_people"],full_df['happiness_score'])
sorted_order = np.argsort(full_df["clean_water_per_100_people"])
plt.plot(full_df["clean_water_per_100_people"][sorted_order], predictions[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('Clean Water per 100 people')
fig.suptitle("Relationship between Clean Water and World Happiness", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Clean Water and World Happiness')

# %% [markdown]
# A positive linear relationship is observed between World Happiness and GDP per capita
# The Slope tells us that for every one unit increase in GDP, there is an increase of 0.770 in the happiness score

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["clean_water_per_100_people"], residuals)
sorted_order = np.argsort(full_df["clean_water_per_100_people"])
plt.plot([full_df["clean_water_per_100_people"].min(), full_df["clean_water_per_100_people"].max()], [0,0], linestyle='dotted')
plt.xlabel('Clean Water')
plt.ylabel('Happiness Score')
fig.suptitle('Relationship between Clean Water and World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Clean Water and World Happiness')

# %% [markdown]
# #### R-squared Value

# %%
np.var(predictions) / np.var(full_df["clean_water_per_100_people"])
# Out:
# 0.0011863918488008499

# %% [markdown]
# #### Analysis

# %% [markdown]
# There is an R-squared value of 44.29% here depicts 44.29% of the variation in the Happiness Score is accounted for by its regression on GDP per capita.

# %% [markdown]
# #### Confidence Intervals and Predication Intervals

# %%
ci, pi = get_intervals(full_df["clean_water_per_100_people"], full_df["happiness_score"], residuals)
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["clean_water_per_100_people"],full_df["happiness_score"])
sorted_order = np.argsort(full_df["clean_water_per_100_people"])
plt.plot(full_df["clean_water_per_100_people"][sorted_order], predictions[sorted_order], label='Regression Line')
plt.plot(full_df["clean_water_per_100_people"][sorted_order], (predictions + ci)[sorted_order], color='orange', label='Confidence Interval')
plt.plot(full_df["clean_water_per_100_people"][sorted_order], (predictions - ci)[sorted_order], color='orange', label='_Confidence Interval')
plt.plot(full_df["clean_water_per_100_people"][sorted_order], (predictions + pi)[sorted_order], color='red', label='Prediction Interval', linestyle='dotted')
plt.plot(full_df["clean_water_per_100_people"][sorted_order], (predictions - pi)[sorted_order], color='red', label='_Prediction Interval', linestyle='dotted')
plt.xlabel('Clean Water')
plt.ylabel('Happiness Score')
plt.legend()
fig.suptitle('World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'World Happiness')

# %% [markdown]
# ### Observation:
#
# The orange lines are the 95% confidence interval of where the mean Y value for a given X value will lay, and the red lines are the 95% confidence interval of where a new Y value for a given X value could land. Most of the observed points are between the red lines - as 95% of them should be.

# %% [markdown]
# ### 5. `happiness_score` vs `doctors_per_10000_people`

# %%
slope, intercept, predictions, residuals = evaluate_linear_relationship(full_df["doctors_per_10000_people"], full_df['happiness_score'])

# %%
print("Slope is ", slope)
print("Interscept is", intercept)
# Out:
# Slope is  0.056062399580486186
# Interscept is 4.5269149356032345

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["doctors_per_10000_people"],full_df['happiness_score'])
sorted_order = np.argsort(full_df["doctors_per_10000_people"])
plt.plot(full_df["doctors_per_10000_people"][sorted_order], predictions[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('Doctors Per 10000 people')
fig.suptitle("Relationship between Doctors Per 10000 people and World Happiness", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Doctors Per 10000 people and World Happiness')

# %% [markdown]
# A positive linear relationship is observed between World Happiness and GDP per capita
# The Slope tells us that for every one unit increase in GDP, there is an increase of 0.770 in the happiness score

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["doctors_per_10000_people"], residuals)
sorted_order = np.argsort(full_df["doctors_per_10000_people"])
plt.plot([full_df["doctors_per_10000_people"].min(), full_df["doctors_per_10000_people"].max()], [0,0], linestyle='dotted')
plt.xlabel('Doctors Per 10000 People')
plt.ylabel('Happiness Score')
fig.suptitle('Relationship between Doctors Per 10000 People and World Happiness', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between Doctors Per 10000 People and World Happiness')

# %% [markdown]
# #### R-squared Value

# %%
np.var(predictions) / np.var(full_df["doctors_per_10000_people"])
# Out:
# 0.0031429926467220998

# %% [markdown]
# #### Analysis

# %% [markdown]
# There is an R-squared value of 59.43% here depicts 59.43% of the variation in the Happiness Score is accounted for by its regression on doctors_per_10000_people.

# %% [markdown]
# ***
