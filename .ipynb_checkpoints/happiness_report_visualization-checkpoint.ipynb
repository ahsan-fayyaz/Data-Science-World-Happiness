# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
import matplotlib.image as mpimg
import scipy.stats as stats

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings; warnings.filterwarnings(action='once')

large = 22; med = 16; small = 12
params = {'axes.titlesize': large,
          'legend.fontsize': med,
          'figure.figsize': (16, 10),
          'axes.labelsize': med,
          'axes.titlesize': med,
          'xtick.labelsize': med,
          'ytick.labelsize': med,
          'figure.titlesize': large}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
# %matplotlib inline

# %%
CWH = pd.read_csv("./Datasets/Cleaned_Datasets/cleaned_world_happiness.csv", header=0)

# %%
CWH.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 7 columns):
# country            155 non-null object
# happiness_score    155 non-null float64
# gdp_per_capita     155 non-null float64
# social_support     155 non-null float64
# life_expectancy    155 non-null float64
# freedom            155 non-null float64
# corruption         155 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 8.6+ KB

# %%
CWH.corr(method="pearson")["happiness_score"].sort_values(ascending=False)
# Out:
# happiness_score    1.000000
# gdp_per_capita     0.842753
# life_expectancy    0.814451
# social_support     0.780656
# freedom            0.618005
# corruption        -0.466333
# Name: happiness_score, dtype: float64

# %%
CWH_Corr = CWH.corr(method = "pearson")
plt.figure(figsize = (20,10))
sb.heatmap(CWH_Corr, annot = True)

# %%
CWH.describe()
# Out:
#        happiness_score  gdp_per_capita  social_support  life_expectancy  \
# count       155.000000      155.000000      155.000000       155.000000
# mean          5.405790        9.280013        0.804541        62.593782
# std           1.072046        1.190757        0.115418         7.588538
# min           3.514954        6.722510        0.402559        43.356001
# 25%           4.502607        8.380180        0.744179        56.795158
# 50%           5.305872        9.340905        0.818085        64.813334
# 75%           6.250837       10.254045        0.899694        67.815385
# max           7.680305       11.607032        0.977578        75.358461
#
#           freedom  corruption
# count  155.000000  155.000000
# mean     0.739016    0.740657
# std      0.123508    0.177650
# min      0.451014    0.097752
# 25%      0.658799    0.695878
# 50%      0.744782    0.794977
# 75%      0.826783    0.846063
# max      0.954373    0.953186

# %%
CWH.sort_values(by = "happiness_score", ascending = False). head(10)
# Out:
#          country  happiness_score  gdp_per_capita  social_support  \
# 37       Denmark         7.680305       10.879287        0.957209
# 45       Finland         7.597216       10.749943        0.948971
# 133  Switzerland         7.548228       11.095401        0.943610
# 105       Norway         7.512566       11.039174        0.950364
# 99   Netherlands         7.466292       10.886792        0.933519
# 59       Iceland         7.446581       10.860745        0.977578
# 25        Canada         7.376319       10.748257        0.935470
# 132       Sweden         7.369527       10.819609        0.927842
# 100  New Zealand         7.310304       10.583125        0.952875
# 6      Australia         7.282024       10.755507        0.947253
#
#      life_expectancy   freedom  corruption
# 37         71.169333  0.945131    0.200404
# 45         71.180000  0.939703    0.248932
# 133        73.334000  0.924874    0.305930
# 105        72.670000  0.954373    0.344084
# ...

# %%
CWH.sort_values(by = "happiness_score", ascending = True). head(10)
# Out:
#                       country  happiness_score  gdp_per_capita  \
# 26   Central African Republic         3.514954        6.960998
# 22                    Burundi         3.548124        6.722510
# 139                      Togo         3.555060        7.239263
# 0                 Afghanistan         3.594628        7.650843
# 117                    Rwanda         3.654473        7.451130
# 137                  Tanzania         3.697284        7.700381
# 154                  Zimbabwe         3.882689        7.850429
# 152                     Yemen         3.912124        8.102699
# 30                    Comoros         3.943963        7.991248
# 56                      Haiti         3.954194        7.446694
#
#      social_support  life_expectancy   freedom  corruption
# 26         0.402559        43.356001  0.680430    0.842129
# 22         0.417652        50.916000  0.451014    0.732270
# 139        0.456104        52.837778  0.623363    0.803149
# ...

# %%
g0 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['gdp_per_capita'])

g1 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['social_support'])

g0.savefig('g0.png', dpi=300)
plt.close(g0.fig)

g1.savefig('g1.png', dpi=300)
plt.close(g1.fig)


############### 2. CREATE YOUR SUBPLOTS FROM TEMPORAL IMAGES
f, axarr = plt.subplots(1, 2, figsize=(40, 40))

axarr[0].imshow(mpimg.imread('g0.png'))
axarr[1].imshow(mpimg.imread('g1.png'))

# turn off x and y axis
[ax.set_axis_off() for ax in axarr.ravel()]

plt.tight_layout()
plt.show()

# %%
g0 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['life_expectancy'])

g1 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['freedom'])

g0.savefig('g0.png', dpi=300)
plt.close(g0.fig)

g1.savefig('g1.png', dpi=300)
plt.close(g1.fig)


############### 2. CREATE YOUR SUBPLOTS FROM TEMPORAL IMAGES
f, axarr = plt.subplots(1, 2, figsize=(40, 40))

axarr[0].imshow(mpimg.imread('g0.png'))
axarr[1].imshow(mpimg.imread('g1.png'))

# turn off x and y axis
[ax.set_axis_off() for ax in axarr.ravel()]

plt.tight_layout()
plt.show()

# %%
g0 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['generosity'])

g1 = sb.pairplot(data=CWH, kind='scatter', height = 2, hue = "happiness_score",
            x_vars=['happiness_score'], y_vars=['corruption'])

# g0.savefig('g0.png', dpi=300)
plt.close(g0.fig)

# g1.savefig('g1.png', dpi=300)
plt.close(g1.fig)


############### 2. CREATE YOUR SUBPLOTS FROM TEMPORAL IMAGES
f, axarr = plt.subplots(1, 2, figsize=(40, 40))

axarr[0].imshow(mpimg.imread('g0.png'))
axarr[1].imshow(mpimg.imread('g1.png'))

# turn off x and y axis
[ax.set_axis_off() for ax in axarr.ravel()]

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'generosity'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-271ccabc541d> in <module>
# ...

# %%
sb.displot(CWH['happiness_score'], kind="kde")

# %% [markdown]
# ***

# %% [markdown]
# # Import Full Dataset

# %%
full_df = pd.read_csv("./Datasets/Cleaned_Datasets/full_dataset.csv", header=0)
full_df.head(15)
# Out:
#         country  happiness_score  gdp_per_capita  social_support  \
# 0   Afghanistan         3.594628        7.650843        0.508245
# 1       Albania         5.019427        9.384397        0.716316
# 2       Algeria         5.389717        9.328897        0.803582
# 3        Angola         4.420299        8.989725        0.737973
# 4     Argentina         6.310166       10.033868        0.904423
# 5       Armenia         4.513624        9.270409        0.718620
# 6     Australia         7.282024       10.755507        0.947253
# 7       Austria         7.242227       10.886958        0.929600
# 8    Azerbaijan         4.940989        9.519592        0.770649
# 9       Bahrain         6.001723       10.730848        0.880093
# 10   Bangladesh         4.754565        8.128453        0.607105
# 11      Belarus         5.571155        9.760055        0.906551
# 12      Belgium         6.981520       10.798704        0.920018
# ...

# %% [markdown]
# # Data Correlation Visualizations

# %% [markdown]
# Our dependent variable that we want to predict is `happiness_score`
# Taking a look at how different features correlate with it will help get a solid understanding of our data

# %%
# This function will help to evaluate linear relationship for two variables

def evaluate_linear_relationship(a, b):
    slope = np.cov(a, b, bias=True)[0][1] / np.var(a)
    intercept = np.mean(b) - (slope * np.mean(a))
    predictions = (slope * a) + intercept
    residuals = b - predictions
    return slope, intercept, predictions, residuals

# %% [markdown]
# ### 1. `happiness_score` vs `gdp_per_capita`

# %%
categories = np.unique(midwest['category'])

# %%
slope_gdp, intercept_gdp, predictions_gdp, residuals_gdp = evaluate_linear_relationship(full_df['happiness_score'],full_df["gdp_per_capita"])

# %%
print("Slope is ", slope_gdp)
print("Interscept is", intercept_gdp)
# Out:
# Slope is  0.9303021216127871
# Interscept is 4.254787984259684

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df['happiness_score'],full_df["gdp_per_capita"])
sorted_order = np.argsort(full_df['happiness_score'])
plt.plot(full_df['happiness_score'][sorted_order], predictions_gdp[sorted_order])
plt.ylabel("Happiness Score")
plt.xlabel('GDP Per Capita')
fig.suptitle("Relationship between GDP and World Happiness", fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between GDP and World Happiness')

# %%
np.power(stats.pearsonr(full_df['happiness_score'], full_df["gdp_per_capita"])[0], 2)
# Out:
# 0.7172173504627627

# %%
fig = plt.figure(figsize=(15,10))
plt.scatter(full_df["gdp_per_capita"], residuals_gdp)
sorted_order = np.argsort(full_df["gdp_per_capita"])
plt.plot([full_df["gdp_per_capita"].min(), full_df["gdp_per_capita"].max()], [0,0], linestyle='dotted')
plt.xlabel('GDP')
plt.ylabel('Happiness')
fig.suptitle('Relationship between years and the average annual temperatures', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Relationship between years and the average annual temperatures')

# %% [markdown]
# ### 2. `happiness_score` vs `social_support`

# %% [markdown]
# ### 3. `happiness_score` vs `life_expectancy`

# %% [markdown]
# ### 4. `happiness_score` vs `freedom`

# %% [markdown]
# ### 5. `happiness_score` vs `corruption`

# %% [markdown]
# ### 6. `happiness_score` vs `clean_water_per_100_people`

# %% [markdown]
# ### 7. `happiness_score` vs `suicide_rate_per_100000_people`

# %% [markdown]
# ### 8. `happiness_score` vs `doctors_per_10000_people`
